# %%
import pandas as pd
from pathlib import Path

# Définir le chemin vers le fichier Parquet
file_path = Path("data/silver/20250416/canal_digitaal/Canal Digitaal_Device_20250416.parquet")

# Lire le fichier
df = pd.read_parquet(file_path)

# Afficher un aperçu
df.head()
# Out:
#                                  UserId BoxType  \
# 0  846e4b3f-1133-b9e5-9d30-52ac6a32c389     stb
# 1  91870cfb-039b-1e74-a0bc-73c5a03408f2     stb
# 2  d5e15868-7d93-36de-16be-2857246d8a9d     stb
# 3  c14762b6-e3e6-2df3-a33c-2f0ebbd811b7     web
# 4  93c97aa0-1e6c-a1ef-61f7-021a0cd0ceed     web
#
#                                   Serial    Model                OS  \
# 0                       00:03:e:f3:a7:e0     None              None
# 1                      00:03:e6:b3:e9:92  Aria600  14.8.104_build6-
# 2                      00:16:6b:ff:3b:2d     EVOS               110
# 3   00000000-0000-4000-8080-d396e1010000     Kodi             Linux
# 4  004wpc2lq-z3n1-63p9-x7be-gdn1d0322m7n     None              None
#
#             App        FirstActivity         LastActivity    OEM SubType
# 0          None  0001-01-01 00:00:00  0001-01-01 00:00:00   None    None
# 1        127786  2024-10-31 10:46:25  2024-10-31 14:00:07  Amino  entone
# 2         49386  2016-01-18 11:03:02  0001-01-01 00:00:00   None    None
# 3  97.0.4692.71  0001-01-01 00:00:00  2023-07-27 10:31:27   None    None
# 4          None  0001-01-01 00:00:00  2025-04-04 02:08:54   None    None

# %%
import pandas as pd
from pathlib import Path

# Définir le chemin vers le fichier Parquet
file_path = Path("data/gold/Device_20250416.parquet")

# Lire le fichier
df = pd.read_parquet(file_path)

# Afficher un aperçu
df.head()
# Out:
#                                  UserId BoxType  \
# 0  d4ea1dd9-14a5-432a-feba-56343f02074a     web
# 1  5e758086-a2f5-bffe-6393-d9d7a5f46eb6     stb
# 2  8993fc21-10fb-44b4-8bed-c55f44268a8c     stb
# 3  350cf96f-b7cd-1e5b-ff1d-e98a4ca69686     ctv
# 4  a336e7b9-1f15-131e-9248-5d06d8835860     stb
#
#                                   Serial    Model                OS     App  \
# 0  w65d00e20-9687-11ef-bfd4-d7f27eb32b8d     Edge        Android 13    11.4
# 1                      5c:0f:fb:0a:18:ce  Aria700  20.2.104_build6-  130835
# 2                      44:f0:34:7c:32:39    MZ101               332   63005
# 3        androidtv.m7cp.9792aed6200a2bcc  EcoTV D                11  132012
# 4                      5c:0f:fb:27:fc:68  Aria700  20.2.104_build6-  132012
#
#          FirstActivity         LastActivity    OEM  SubType  \
# 0  0001-01-01 00:00:00  2024-10-30 11:48:05   Edge     None
# 1  2021-10-29 06:53:56  2025-04-17 01:37:23  Amino   entone
# 2  2019-07-11 20:18:57  2019-07-15 01:00:05   None     None
# 3  0001-01-01 00:00:00  2025-04-14 17:48:24    KTC  android
# 4  2024-01-30 11:26:29  2025-04-17 01:30:44  Amino   entone
#
#                        BRAND  FILEDATE
# 0  Canal Digitaal  Resellers  20250416
# 1  Canal Digitaal  Resellers  20250416
# 2  Canal Digitaal  Resellers  20250416
# 3  Canal Digitaal  Resellers  20250416
# 4  Canal Digitaal  Resellers  20250416
