# %%
import pandas as pd
from pathlib import Path

# Définir le chemin vers le fichier Parquet
file_path = Path("data/silver/20250416/canal_digitaal/Canal Digitaal_Device_20250416.parquet")

# Lire le fichier
df = pd.read_parquet(file_path)

# Afficher un aperçu
df.head()
# Out:
#                                  UserId BoxType  \
# 0  846e4b3f-1133-b9e5-9d30-52ac6a32c389     stb
# 1  91870cfb-039b-1e74-a0bc-73c5a03408f2     stb
# 2  d5e15868-7d93-36de-16be-2857246d8a9d     stb
# 3  c14762b6-e3e6-2df3-a33c-2f0ebbd811b7     web
# 4  93c97aa0-1e6c-a1ef-61f7-021a0cd0ceed     web
#
#                                   Serial    Model                OS  \
# 0                       00:03:e:f3:a7:e0     None              None
# 1                      00:03:e6:b3:e9:92  Aria600  14.8.104_build6-
# 2                      00:16:6b:ff:3b:2d     EVOS               110
# 3   00000000-0000-4000-8080-d396e1010000     Kodi             Linux
# 4  004wpc2lq-z3n1-63p9-x7be-gdn1d0322m7n     None              None
#
#             App        FirstActivity         LastActivity    OEM SubType
# 0          None  0001-01-01 00:00:00  0001-01-01 00:00:00   None    None
# 1        127786  2024-10-31 10:46:25  2024-10-31 14:00:07  Amino  entone
# 2         49386  2016-01-18 11:03:02  0001-01-01 00:00:00   None    None
# 3  97.0.4692.71  0001-01-01 00:00:00  2023-07-27 10:31:27   None    None
# 4          None  0001-01-01 00:00:00  2025-04-04 02:08:54   None    None

# %%
import pandas as pd
from pathlib import Path

# Définir le chemin vers le fichier Parquet
file_path = Path("data/gold/Playback_20250416.parquet")

# Lire le fichier
df = pd.read_parquet(file_path)

# Afficher un aperçu
df.head()
# Out:
#                           PlaySessionID        PlayStartTime  \
# 0  523f9601-6b7e-568c-834e-00007b724fa9  2025-04-16 15:58:10
# 1  22409601-4b1a-c389-9e9a-0000edfd2271  2025-04-16 19:45:01
# 2  d13f9601-14b1-5e85-9ccb-0001096118bf  2025-04-16 18:17:09
# 3  b23d9601-6a84-d98f-8c04-0001146af733  2025-04-16 08:23:52
# 4  313f9601-cc65-2c8a-9844-000121fed585  2025-04-16 15:22:04
#
#                                  UserId                                 SSOID  \
# 0  9cac6e83-88aa-14b0-0b68-60740360d622                        12857125497286
# 1  0d5b01ba-50d4-dd1b-40ad-e55d87d2b78f  e6c95d72-6ba6-4561-9ba4-f90023d8c66f
# 2  d46d93c9-d514-a6b3-edc7-9cb9fbdea6a4                           33731602422
# 3  abf40d59-5160-8082-e8c5-0f534eef0684                          051603686180
# 4  4ff0091c-f26f-f02b-9f28-edd21e3a1f38                           33731502044
#
#   AssetType AssetID     AssetName AssetSolocooID AssetOwner  AssetDuration  \
# 0         s   10015       nl_NPO2          10015       None              0
# 1         s     187       nl_ESPN            187       None              0
# 2         s     158     de_RTL2SD            158       None              0
# 3         s      69       nl_RTL4             69       None              0
# 4         s     226  de_WDR_Koeln            226       None              0
#
#    ...  ChannelName                 Date UserFlags  MemberId IsKidsMember  \
# 0  ...         None  2025-04-16 00:00:00   2032642         0        False
# 1  ...         None  2025-04-16 00:00:00   2032642         0        False
# 2  ...         None  2025-04-16 00:00:00   1639426         0        False
# 3  ...         None  2025-04-16 00:00:00   4129794         1        False
# 4  ...         None  2025-04-16 00:00:00   4129794         0        False
#
#   Protocol                              TVAPIAssetId SeriesTVAPIAssetId  \
# 0    https  cmEptSYiJIyHWcaSP1PAWirLQUbXUqTm3Xeq-bF0               None
# 1    https  K0Y-FZZNgbg-JTm3UcTFo3KtNPbhRJQOoagUXH4E               None
# 2     dvbs  BEhLG_RwjRKI5RCxHvRofhh2CoPqkiQUMCXrrjL1               None
# 3     dvbs  UZ823Q9iXs61u7D-6MIM5VQ-ZSTbu8FY8ubr0YEc               None
# 4     dvbs  dLoS4rjAJ1kmZxY1tQs9TQR3GbyPnKwmmncvro4s               None
#
#             BRAND  FILEDATE
# 0  Canal Digitaal  20250416
# 1  Canal Digitaal  20250416
# 2  Canal Digitaal  20250416
# 3  Canal Digitaal  20250416
# 4  Canal Digitaal  20250416
#
# [5 rows x 31 columns]
